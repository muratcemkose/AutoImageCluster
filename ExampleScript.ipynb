# %%
import os
import numpy as np
import pandas as pd
from datetime import datetime
from datetime import date
from tqdm import tqdm_notebook
import warnings
warnings.filterwarnings("ignore")
import shutil
import utils
import AutoImageCluster

# %%
### Input path where the images are located
images_path = "/Users/muratckose/Desktop/Phone backup 2022 Sep 17/camera/"
### Output path where the images will be sorted at
destination_path = "/Users/muratckose/Desktop/Fotos/"

# %%
obj = AutoImageCluster.AutoImageClusterObject(images_path=images_path, destination_path=destination_path)

# %%
obj.read_and_categorize_images()
# Out:
# Number of all images: 7479
# Number of images with location and date information: 4105
# Number of images with only date information: 3365
# Number of images neither information: 9

# %%
obj.group_and_predict_year_and_geolocation()
# Out:
# Clustering procedure is initiated:
#   0%|          | 0/3 [00:00<?, ?it/s]
# For the year of 2020
# Model accuracy for cities:
# 0.9658792650918635
# Model accuracy for countries:
# 0.994750656167979
# Would you like to see the picture locations on a real map? Yes? No?
#  Yes
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
# ...

# %%
obj.copy_images_to_new_loc()
# Out:
#   0%|          | 0/7479 [00:00<?, ?it/s]

# %%
! jupyter nbconvert --to html "ExampleScript.ipynb"
# Out:
# [NbConvertApp] Converting notebook ExampleScript.ipynb to html
# [NbConvertApp] Writing 2836756 bytes to ExampleScript.html
